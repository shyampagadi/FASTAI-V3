# %% [markdown]
# <a href="https://colab.research.google.com/github/shyampagadi/FASTAI-V3/blob/master/Intel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget --header='Host: datahack-prod.s3.amazonaws.com' --header='User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.119 Safari/537.36' --header='Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8' 'https://datahack-prod.s3.amazonaws.com/test_file/test_WyRytb0.csv' -O 'test_WyRytb0.csv' -c
# Out:
# --2019-02-28 06:51:52--  https://datahack-prod.s3.amazonaws.com/test_file/test_WyRytb0.csv
# Resolving datahack-prod.s3.amazonaws.com (datahack-prod.s3.amazonaws.com)... 52.219.66.44
# Connecting to datahack-prod.s3.amazonaws.com (datahack-prod.s3.amazonaws.com)|52.219.66.44|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69660 (68K) [application/vnd.ms-excel]
# Saving to: ‘test_WyRytb0.csv’
#
# test_WyRytb0.csv    100%[===================>]  68.03K   147KB/s    in 0.5s
#
# 2019-02-28 06:51:53 (147 KB/s) - ‘test_WyRytb0.csv’ saved [69660/69660]

# %%
ls
# Out:
# sample_data/  test_WyRytb0.csv

# %%
# !wget https://drive.google.com/open?id=10qN7OUzTutCg8ruwFosml0xzi0elsI5N
# Out:
# --2019-02-28 06:52:00--  https://drive.google.com/open?id=10qN7OUzTutCg8ruwFosml0xzi0elsI5N
# Resolving drive.google.com (drive.google.com)... 64.233.166.102, 64.233.166.139, 64.233.166.113, ...
# Connecting to drive.google.com (drive.google.com)|64.233.166.102|:443... connected.
# HTTP request sent, awaiting response... 307 OK
# Location: https://drive.google.com/file/d/10qN7OUzTutCg8ruwFosml0xzi0elsI5N/view?usp=drive_open [following]
# --2019-02-28 06:52:00--  https://drive.google.com/file/d/10qN7OUzTutCg8ruwFosml0xzi0elsI5N/view?usp=drive_open
# Reusing existing connection to drive.google.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘open?id=10qN7OUzTutCg8ruwFosml0xzi0elsI5N’
#
# open?id=10qN7OUzTut     [ <=>                ] 133.03K  --.-KB/s    in 0.1s
#
# 2019-02-28 06:52:01 (1.27 MB/s) - ‘open?id=10qN7OUzTutCg8ruwFosml0xzi0elsI5N’ saved [136227]

# %%
# !wget --header='Host: storage.googleapis.com' --header='User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.119 Safari/537.36' --header='Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8' 'https://storage.googleapis.com/kaggle-datasets/121262/292122/intel-data-scene.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1551516339&Signature=YXd2LZMbTft9EHKXm%2BoZaIxO7KJy0ASOXlSjq997vBWDOmRohDRHCkIvDISXf1iPleiZMU%2BmlR%2B1hs5tR06DBXMb4OfLzWmjsGKq0zbkeERPqGbXDg1qIEZTj7GOsWk%2FlHLHM9CNK4Fem3VuoMpU4INU8KFvzkT2UJSmkS%2FDVdOLxkZbBK%2FgsoVZptI36cThZCtGS2hNOEvncZ88yuRh0a06G37mrg2elG59lvaOJikUGh2QBh9up2xmG1shKf3sSw8XfK7H4mS0wj5CEjnR9AfKa88%2FrYGp4U1XQk3G0aNyFCy35NZjwgEUgw8v5LdWeSUgcoy%2BpKXpdbXZ27oLpw%3D%3D' -O 'intel-data-scene.zip' -c
# Out:
# --2019-02-28 06:52:02--  https://storage.googleapis.com/kaggle-datasets/121262/292122/intel-data-scene.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1551516339&Signature=YXd2LZMbTft9EHKXm%2BoZaIxO7KJy0ASOXlSjq997vBWDOmRohDRHCkIvDISXf1iPleiZMU%2BmlR%2B1hs5tR06DBXMb4OfLzWmjsGKq0zbkeERPqGbXDg1qIEZTj7GOsWk%2FlHLHM9CNK4Fem3VuoMpU4INU8KFvzkT2UJSmkS%2FDVdOLxkZbBK%2FgsoVZptI36cThZCtGS2hNOEvncZ88yuRh0a06G37mrg2elG59lvaOJikUGh2QBh9up2xmG1shKf3sSw8XfK7H4mS0wj5CEjnR9AfKa88%2FrYGp4U1XQk3G0aNyFCy35NZjwgEUgw8v5LdWeSUgcoy%2BpKXpdbXZ27oLpw%3D%3D
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.206.128, 2a00:1450:400c:c04::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.206.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 492522414 (470M) [application/zip]
# Saving to: ‘intel-data-scene.zip’
#
# intel-data-scene.zi 100%[===================>] 469.71M  55.5MB/s    in 8.9s
#
# ...

# %%
# !wget --header='Host: datahack-prod.s3.amazonaws.com' --header='User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.119 Safari/537.36' --header='Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8' 'https://datahack-prod.s3.amazonaws.com/sample_submission/sample_submission_CH2mq5Z.csv' -O 'sample_submission_CH2mq5Z.csv' -c
# Out:
# --2019-02-28 06:52:14--  https://datahack-prod.s3.amazonaws.com/sample_submission/sample_submission_CH2mq5Z.csv
# Resolving datahack-prod.s3.amazonaws.com (datahack-prod.s3.amazonaws.com)... 52.219.66.16
# Connecting to datahack-prod.s3.amazonaws.com (datahack-prod.s3.amazonaws.com)|52.219.66.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84268 (82K) [text/csv]
# Saving to: ‘sample_submission_CH2mq5Z.csv’
#
# sample_submission_C 100%[===================>]  82.29K   179KB/s    in 0.5s
#
# 2019-02-28 06:52:16 (179 KB/s) - ‘sample_submission_CH2mq5Z.csv’ saved [84268/84268]

# %%
# !mkdir -p data1/intel

# %%
# !unzip intel-data-scene.zip -d data1/intel
# Out:
# Archive:  intel-data-scene.zip
#    creating: data1/intel/scene_classification/
#   inflating: data1/intel/scene_classification/train.csv
#    creating: data1/intel/scene_classification/test/
#   inflating: data1/intel/scene_classification/test/28.jpg
#   inflating: data1/intel/scene_classification/test/52.jpg
#   inflating: data1/intel/scene_classification/test/64.jpg
#   inflating: data1/intel/scene_classification/test/73.jpg
#   inflating: data1/intel/scene_classification/test/133.jpg
#   inflating: data1/intel/scene_classification/test/182.jpg
#   inflating: data1/intel/scene_classification/test/203.jpg
#   inflating: data1/intel/scene_classification/test/242.jpg
#   inflating: data1/intel/scene_classification/test/244.jpg
#   inflating: data1/intel/scene_classification/test/302.jpg
#   inflating: data1/intel/scene_classification/test/303.jpg
#   inflating: data1/intel/scene_classification/test/324.jpg
#   inflating: data1/intel/scene_classification/test/327.jpg
# ...

# %%
# !pip install fastai
from fastai import *
from fastai.vision import *

path =  Path('data1/intel/scene_classification')

# %%
import fastai
fastai.__version__
# Out:
# '1.0.46'

# %%
# !cp test_WyRytb0.csv {path}

# %%
# !cp sample_submission_CH2mq5Z.csv {path}

# %%
path.ls()
# Out:
# [PosixPath('data1/intel/scene_classification/train.csv'),
#  PosixPath('data1/intel/scene_classification/test'),
#  PosixPath('data1/intel/scene_classification/train'),
#  PosixPath('data1/intel/scene_classification/sample_submission_CH2mq5Z.csv'),
#  PosixPath('data1/intel/scene_classification/test_WyRytb0.csv')]

# %%
bs = 64

# %%
lab = {'buildings':0, 
'forest':1,
'glacier':2,
'mountain':3,
'sea':4,
'street':5 }

# %%
# lab('buildings')

# %%
df = pd.read_csv(path/'train.csv')

df.head()
# Out:
#   image_name  label
# 0      0.jpg      0
# 1      1.jpg      4
# 2      2.jpg      5
# 3      4.jpg      0
# 4      7.jpg      4

# %%
s = pd.Series(df.label)
s = s.map({0:'buildings',1:'forest',2:'glacier',3:'mountain',4:'sea',5:'street'})
s.head()
df['label'] = s

df.to_csv(path/'train_m.csv',index=False)

# %%
path.ls()
# Out:
# [PosixPath('data1/intel/scene_classification/train.csv'),
#  PosixPath('data1/intel/scene_classification/test'),
#  PosixPath('data1/intel/scene_classification/train_m.csv'),
#  PosixPath('data1/intel/scene_classification/train'),
#  PosixPath('data1/intel/scene_classification/sample_submission_CH2mq5Z.csv'),
#  PosixPath('data1/intel/scene_classification/test_WyRytb0.csv')]

# %%
dff = pd.read_csv(path/'train_m.csv')
dff.head()
# Out:
#   image_name      label
# 0      0.jpg  buildings
# 1      1.jpg        sea
# 2      2.jpg     street
# 3      4.jpg  buildings
# 4      7.jpg        sea

# %%
tfms = get_transforms(do_flip=False)
data = (ImageItemList.from_csv(path, csv_name='train_m.csv',folder='train') #Where to find the data? -> in path and its subfolders
        .random_split_by_pct()              #How to split in train/valid? -> use the folders
        .label_from_df()            #How to label? -> depending on the folder of the filenames
        .add_test_folder(test_folder = 'test')              #Optionally add a test set (here default name is test)
        .transform(tfms, size=128)       #Data augmentation? -> use tfms with a size of 64
        .databunch())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-d69097e29062> in <module>()
#       1 tfms = get_transforms(do_flip=False)
# ----> 2 data = (ImageItemList.from_csv(path, csv_name='train_m.csv',folder='train') #Where to find the data? -> in path and its subfolders
#       3         .random_split_by_pct()              #How to split in train/valid? -> use the folders
#       4         .label_from_df()            #How to label? -> depending on the folder of the filenames
#       5         .add_test_folder(test_folder = 'test')              #Optionally add a test set (here default name is test)
#
# NameError: name 'ImageItemList' is not defined

# %%
data.show_batch(rows=3, figsize=(8,10))

# %%
learn = create_cnn(data, models.resnet34, metrics=[error_rate, accuracy])
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.torch/models/resnet34-333f7ec4.pth
# 87306240it [00:00, 90624130.52it/s]

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 04:37 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.500792</td>
#       <td>0.320201</td>
#       <td>0.119789</td>
#       <td>0.880211</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.362662</td>
#       <td>0.251661</td>
#       <td>0.091897</td>
#       <td>0.908103</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.294006</td>
#       <td>0.228278</td>
#       <td>0.080153</td>
#       <td>0.919847</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.263267</td>
#       <td>0.222100</td>
#       <td>0.078685</td>
#       <td>0.921315</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 9.12E-07

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(4, max_lr=slice(1e-6, 1e-4))
# Out:
# Total time: 04:51 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.252366</td>
#       <td>0.209262</td>
#       <td>0.071345</td>
#       <td>0.928655</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.226306</td>
#       <td>0.196758</td>
#       <td>0.070464</td>
#       <td>0.929536</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.208223</td>
#       <td>0.184885</td>
#       <td>0.066060</td>
#       <td>0.933940</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.185873</td>
#       <td>0.186886</td>
#       <td>0.065473</td>
#       <td>0.934527</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(4, max_lr=slice(1e-6, 1e-4))
# Out:
# Total time: 04:51 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.178089</td>
#       <td>0.181976</td>
#       <td>0.064005</td>
#       <td>0.935995</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.166176</td>
#       <td>0.181508</td>
#       <td>0.064592</td>
#       <td>0.935408</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.157308</td>
#       <td>0.175514</td>
#       <td>0.061950</td>
#       <td>0.938051</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.134659</td>
#       <td>0.175458</td>
#       <td>0.063418</td>
#       <td>0.936583</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2-128')

# %%
tfms = get_transforms(do_flip=False)
data = (ImageList.from_csv(path, csv_name='train_m.csv',folder='train') #Where to find the data? -> in path and its subfolders
        .random_split_by_pct()              #How to split in train/valid? -> use the folders
        .label_from_df()            #How to label? -> depending on the folder of the filenames
        .add_test_folder(test_folder = 'test')              #Optionally add a test set (here default name is test)
        .transform(tfms, size=224)       #Data augmentation? -> use tfms with a size of 64
        .databunch())

# %%
learn = create_cnn(data, models.resnet34, metrics=[error_rate, accuracy])
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.torch/models/resnet34-333f7ec4.pth
# 87306240it [00:01, 73215583.37it/s]

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 09:19 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.418781</td>
#       <td>0.274779</td>
#       <td>0.100998</td>
#       <td>0.899002</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.289932</td>
#       <td>0.226339</td>
#       <td>0.084850</td>
#       <td>0.915150</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.237554</td>
#       <td>0.206982</td>
#       <td>0.077510</td>
#       <td>0.922490</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.212003</td>
#       <td>0.204196</td>
#       <td>0.074868</td>
#       <td>0.925132</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-224')

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 3.02E-05

# %%
learn.fit_one_cycle(10, max_lr=slice(5e-5, 5e-4))
# Out:
# Total time: 26:10 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.191905</td>
#       <td>0.194889</td>
#       <td>0.074868</td>
#       <td>0.925132</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.209229</td>
#       <td>0.213828</td>
#       <td>0.073400</td>
#       <td>0.926600</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.203594</td>
#       <td>0.246401</td>
#       <td>0.084263</td>
#       <td>0.915737</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.158455</td>
#       <td>0.228030</td>
#       <td>0.074281</td>
#       <td>0.925719</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.120441</td>
#       <td>0.236200</td>
#       <td>0.085731</td>
#       <td>0.914269</td>
# ...

# %%
learn.save('stage-2-224')

# %%
tfms = get_transforms(do_flip=False)
data = (ImageList.from_csv(path, csv_name='train_m.csv',folder='train') #Where to find the data? -> in path and its subfolders
        .random_split_by_pct()              #How to split in train/valid? -> use the folders
        .label_from_df()            #How to label? -> depending on the folder of the filenames
        .add_test_folder(test_folder = 'test')              #Optionally add a test set (here default name is test)
        .transform(tfms, size=299)       #Data augmentation? -> use tfms with a size of 64
        .databunch())

# %%
learn = create_cnn(data, models.resnet34, metrics=[error_rate, accuracy])

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 15:47 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.404985</td>
#       <td>0.249961</td>
#       <td>0.094245</td>
#       <td>0.905755</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.302885</td>
#       <td>0.201486</td>
#       <td>0.075455</td>
#       <td>0.924545</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.245638</td>
#       <td>0.185255</td>
#       <td>0.070757</td>
#       <td>0.929242</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.211851</td>
#       <td>0.175720</td>
#       <td>0.065766</td>
#       <td>0.934234</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-299')

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 1.10E-06

# %%
learn.fit_one_cycle(5, max_lr=slice(1e-6, 1e-4))
# Out:
# Total time: 23:44 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.195032</td>
#       <td>0.170578</td>
#       <td>0.066353</td>
#       <td>0.933647</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.188305</td>
#       <td>0.158936</td>
#       <td>0.059307</td>
#       <td>0.940693</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.169105</td>
#       <td>0.152194</td>
#       <td>0.058426</td>
#       <td>0.941574</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.139812</td>
#       <td>0.150044</td>
#       <td>0.058426</td>
#       <td>0.941574</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.131916</td>
#       <td>0.150634</td>
#       <td>0.057546</td>
#       <td>0.942455</td>
# ...

# %%
learn.save('stage-2-299')

# %%
learn.fit_one_cycle(5, max_lr=slice(1e-6, 1e-4))
# Out:
# Total time: 23:43 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.137119</td>
#       <td>0.149926</td>
#       <td>0.057839</td>
#       <td>0.942161</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.139261</td>
#       <td>0.151772</td>
#       <td>0.057252</td>
#       <td>0.942748</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.115313</td>
#       <td>0.151296</td>
#       <td>0.056371</td>
#       <td>0.943629</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.092006</td>
#       <td>0.151396</td>
#       <td>0.057839</td>
#       <td>0.942161</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.093770</td>
#       <td>0.153436</td>
#       <td>0.057546</td>
#       <td>0.942455</td>
# ...

# %%
learn.save('stage-2-299')

# %%
preds,_ = learn.get_preds(ds_type=DatasetType.Test)

# %%
labelled_preds = []
for pred in preds:
    labelled_preds.append(int(np.argmax(pred)))
    
# labelled_preds[0:10]
len(labelled_preds)
# Out:
# 7301

# %%
import os
filenames = os.listdir(path/'test/')

# %%
len(filenames) == len(labelled_preds)
# Out:
# True

# %%
submission = pd.DataFrame(
    {'image_name': filenames,
     'label': labelled_preds,
    })

# %%
submission.to_csv(path/'first_submission_V3.csv',index = False)

# %%
sb = pd.read_csv(path/'first_submission_V3.csv')
sb.head()
# Out:
#   image_name  label
# 0  14982.jpg      0
# 1  23015.jpg      0
# 2   3648.jpg      2
# 3   9829.jpg      0
# 4   5486.jpg      2

# %%
# from google.colab import files
# files.download(path/'first_submission.csv')

# %%
from google.colab import files
files.download(path/'first_submission_V3.csv')

# %%
tfms = get_transforms(do_flip=False, max_lighting=0.1, max_zoom=1.05, max_warp=0.)
data = (ImageList.from_csv(path, csv_name='train_m.csv',folder='train') #Where to find the data? -> in path and its subfolders
        .random_split_by_pct()              #How to split in train/valid? -> use the folders
        .label_from_df()            #How to label? -> depending on the folder of the filenames
        .add_test_folder(test_folder = 'test')              #Optionally add a test set (here default name is test)
        .transform(tfms, size=299)       #Data augmentation? -> use tfms with a size of 64
        .databunch())

# %%
learn = create_cnn(data, models.resnet50, metrics=[error_rate, accuracy])
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.torch/models/resnet50-19c8e357.pth
# 102502400it [00:01, 62282179.78it/s]

# %%
learn.fit_one_cycle(5)
# Out:
# Total time: 37:30 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.335396</td>
#       <td>0.261155</td>
#       <td>0.093071</td>
#       <td>0.906929</td>
#       <td>07:45</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.278882</td>
#       <td>0.252208</td>
#       <td>0.084263</td>
#       <td>0.915737</td>
#       <td>07:27</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.226125</td>
#       <td>0.204282</td>
#       <td>0.070170</td>
#       <td>0.929830</td>
#       <td>07:26</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.176194</td>
#       <td>0.194754</td>
#       <td>0.068996</td>
#       <td>0.931004</td>
#       <td>07:25</td>
#     </tr>
#     <tr>
# ...

# %%
learn.save('stage-1-299-RN50')

# %%
gc.collect()
# Out:
# 13023

# %%
learn.load('stage-1-299-RN50')

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 2.29E-06

# %%
learn.unfreeze()
learn.fit_one_cycle(5, max_lr=slice(1e-6, 1e-4))
# Out:
# Total time: 47:55 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.147142</td>
#       <td>0.186251</td>
#       <td>0.068409</td>
#       <td>0.931591</td>
#       <td>09:38</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.153901</td>
#       <td>0.178829</td>
#       <td>0.062243</td>
#       <td>0.937757</td>
#       <td>09:34</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.119978</td>
#       <td>0.178788</td>
#       <td>0.062830</td>
#       <td>0.937170</td>
#       <td>09:34</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.103893</td>
#       <td>0.179181</td>
#       <td>0.061950</td>
#       <td>0.938051</td>
#       <td>09:34</td>
#     </tr>
#     <tr>
# ...

# %%
learn.fit_one_cycle(3, max_lr=slice(1e-6, 1e-4))
# Out:
# Total time: 28:46 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.102812</td>
#       <td>0.178292</td>
#       <td>0.059601</td>
#       <td>0.940399</td>
#       <td>09:35</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.093955</td>
#       <td>0.182018</td>
#       <td>0.059307</td>
#       <td>0.940693</td>
#       <td>09:35</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.078640</td>
#       <td>0.177889</td>
#       <td>0.057546</td>
#       <td>0.942455</td>
#       <td>09:35</td>
#     </tr>
#   </tbody>
# </table>

# %%
tfms = get_transforms(do_flip=False, max_lighting=0.1, max_zoom=1.05, max_warp=0.)
data = (ImageList.from_csv(path, csv_name='train_m.csv',folder='train') #Where to find the data? -> in path and its subfolders
        .random_split_by_pct()              #How to split in train/valid? -> use the folders
        .label_from_df()            #How to label? -> depending on the folder of the filenames
        .add_test_folder(test_folder = 'test')              #Optionally add a test set (here default name is test)
        .transform(tfms, size=299)       #Data augmentation? -> use tfms with a size of 64
        .databunch())

# %%
learn = create_cnn(data, models.resnet50, ps=0.7, metrics=[error_rate, accuracy])

# %%
# ?create_cnn

# %%
learn.fit_one_cycle(5)
# Out:
# Total time: 37:09 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.375668</td>
#       <td>0.260373</td>
#       <td>0.096594</td>
#       <td>0.903406</td>
#       <td>07:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.286650</td>
#       <td>0.219312</td>
#       <td>0.081327</td>
#       <td>0.918673</td>
#       <td>07:26</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.243244</td>
#       <td>0.197431</td>
#       <td>0.075749</td>
#       <td>0.924251</td>
#       <td>07:26</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.201351</td>
#       <td>0.193963</td>
#       <td>0.072813</td>
#       <td>0.927187</td>
#       <td>07:25</td>
#     </tr>
#     <tr>
# ...

# %%
learn.unfreeze()
learn.fit_one_cycle(5, max_lr=slice(1e-6, 1e-4))
# Out:
# Total time: 47:53 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.155335</td>
#       <td>0.183271</td>
#       <td>0.068409</td>
#       <td>0.931591</td>
#       <td>09:34</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.156827</td>
#       <td>0.175385</td>
#       <td>0.067528</td>
#       <td>0.932472</td>
#       <td>09:34</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.134854</td>
#       <td>0.174353</td>
#       <td>0.065179</td>
#       <td>0.934821</td>
#       <td>09:34</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.119337</td>
#       <td>0.173937</td>
#       <td>0.063711</td>
#       <td>0.936289</td>
#       <td>09:34</td>
#     </tr>
#     <tr>
# ...

# %%
ls
# Out:
# sample_data/
